# %%
import pandas as pd

df = pd.read_csv("bank-full.csv", delimiter=";")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
df.describe(include="object")
# Out:
#                 job  marital  education default housing   loan   contact  \
# count         45211    45211      45211   45211   45211  45211     45211
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9732    27214      23202   44396   25130  37967     29285
#
#         month poutcome      y
# count   45211    45211  45211
# unique     12        4      2
# top       may  unknown     no
# freq    13766    36959  39922

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    df.drop("y", axis=1), df["y"], test_size=0.3, random_state=26)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (31647, 16)
# (13564, 16)
# (31647,)
# (13564,)

# %%
# create model with pipeline

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier

numeric_features = ["age", "balance", "day", "duration",
                    "campaign", "pdays", "previous"]
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# categorical transfomer
categorical_features = ["job", "marital", "education",
                        "default", "housing", "loan", "contact",
                        "month", "poutcome"]

# categorical transfomer
categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(transformers=[
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features)
])

model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier(n_estimators=100, n_jobs=10, max_depth=34))
])

model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'balance', 'day',
#                                                    'duration', 'campaign',
#                                                    'pdays', 'previous']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['job', 'marital',
#                                                    'education', 'default',
#                                                    'housing', 'loan', 'contact',
#                                                    'month', 'poutcome'])])),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=34, n_jobs=10))])

# %%
# testing

y_pred = model.predict(x_test)

# confussion matrix with label
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.92      0.97      0.95     11955
#          yes       0.67      0.40      0.50      1609
#
#     accuracy                           0.91     13564
#    macro avg       0.80      0.69      0.72     13564
# weighted avg       0.89      0.91      0.89     13564

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", DecisionTreeClassifier())
])

model_dt.fit(x_train, y_train)

y_pred = model_dt.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.93      0.93      0.93     11955
#          yes       0.48      0.48      0.48      1609
#
#     accuracy                           0.88     13564
#    macro avg       0.70      0.71      0.70     13564
# weighted avg       0.88      0.88      0.88     13564

# %%
# create another model with adaboost

from sklearn.ensemble import AdaBoostClassifier

model_ada = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", AdaBoostClassifier())
])

model_ada.fit(x_train, y_train)

y_pred = model_ada.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.92      0.97      0.94     11955
#          yes       0.61      0.33      0.43      1609
#
#     accuracy                           0.90     13564
#    macro avg       0.76      0.65      0.69     13564
# weighted avg       0.88      0.90      0.88     13564

# %% [markdown]
# # bongkar model

# %%
model["classifier"].estimators_
# Out:
# [DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1529737416),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=200311226),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1143563392),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1213926291),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=594819530),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=204383415),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=271232978),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt', random_state=39596097),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1837947254),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1336677672),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1917790793),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1181917272),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=173784757),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=695882809),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt', random_state=58888),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1897707219),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1672190911),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=411431720),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1473034737),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=829742566),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1142581954),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1944466514),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1502043745),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1634623863),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1096757017),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1417823483),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=932790832),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1554587024),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1312004508),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1924489248),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1738431759),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=157921773),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1153728432),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1485336735),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1982171902),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1655307898),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=629655998),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=321748841),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=710874821),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1755916069),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=2119146040),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1790309691),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1457769793),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1255354284),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=2128000214),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1284633412),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=886816712),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=910170902),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1188059215),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1541651230),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1613166417),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=445469368),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=502676750),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1266265330),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1029597631),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=463999221),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1656627116),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1718876131),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1487135668),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1909477010),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=874840874),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=259514850),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=366005729),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=930728792),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=116361365),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1711681008),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1646386601),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=412573759),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt', random_state=95951438),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=598395339),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1574094468),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1391707099),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1522764323),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1807376873),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=794471295),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=936452172),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=2032234292),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=805406140),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=2077330151),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1967887462),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=436178028),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=305565588),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=655307092),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=784545444),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1633749531),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1153915382),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=2104374421),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=764288778),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=922144335),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1018098760),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=906239268),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=413110155),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1609278003),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1343765766),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=698938801),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1074040389),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1967753848),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=693574799),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=875161926),
#  DecisionTreeClassifier(max_depth=34, max_features='sqrt',
#                         random_state=1044555157)]

# %%
from sklearn.metrics import f1_score

y_test_ = y_test.apply(lambda x: 1 if x=="yes" else 0)
for dt in model["classifier"].estimators_:
    x = model["preprocessor"].transform(x_test)
    y_pred = dt.predict(x)
    print(f1_score(y_test_, y_pred))
# Out:
# 0.43586550435865506
# 0.41935483870967744
# 0.43889955214331416
# 0.461961503208066
# 0.4261986837981824
# 0.45414572864321606
# 0.45784654246921375
# 0.40933459476505835
# 0.4448540706605223
# 0.43216392424712824
# 0.4418006430868167
# 0.45247740729199126
# 0.417910447761194
# 0.42111801242236024
# 0.467459324155194
# 0.444583203246956
# 0.425585023400936
# 0.43685365089313694
# 0.43988816402609504
# 0.43390259329538267
# 0.4322274881516588
# 0.4443753884400249
# 0.43744090765836746
# 0.4545738370277865
# 0.44751728472658703
# 0.45796178343949046
# 0.44548872180451127
# 0.4277638190954774
# 0.4370066308809599
# 0.4358647096362476
# 0.4643304130162703
# 0.44941030415890754
# 0.4382093316519546
# 0.43057722308892354
# 0.45946811919256647
# 0.4709897610921502
# 0.4463171036204744
# 0.4137487953742371
# 0.4398003742981909
# 0.45885286783042395
# 0.4683812405446294
# 0.44199243379571246
# 0.4507836990595611
# 0.4448030987734022
# 0.4297674418604651
# 0.4352791878172589
# 0.4563926226945921
# 0.44299065420560746
# 0.46272811630064953
# 0.43993660855784467
# 0.41511771995043373
# 0.44108574953732266
# 0.4594336621062679
# 0.44597989949748745
# 0.43478260869565216
# 0.46292834890965734
# 0.4106750392464678
# 0.4761609907120743
# 0.42112
# 0.4448563484708063
# 0.4647798742138365
# 0.4301693831895174
# 0.43924050632911393
# 0.4355140186915888
# 0.47227300426569163
# 0.4699318040917545
# 0.4356807511737089
# 0.42118537200504413
# 0.4159098026933918
# 0.4394984326018809
# 0.4014755610205964
# 0.4695384615384615
# 0.43200506008855155
# 0.4266999376169682
# 0.4501406689590497
# 0.45743329097839897
# 0.43326039387308535
# 0.4413879337292904
# 0.45931167577999354
# 0.4484998453448809
# 0.44150943396226416
# 0.44563167818981775
# 0.4471820141669233
# 0.4424560320888615
# 0.4573791348600509
# 0.44234998429154887
# 0.4561622464898596
# 0.45098653304102726
# 0.450974327250232
# 0.4517571884984026
# 0.4511930585683297
# 0.45169307238272755
# 0.4599499374217772
# 0.43462246777163904
# 0.4550632911392405
# 0.44478812248685434
# 0.4499685336689742
# 0.4217473287240729
# 0.4589252625077208
# 0.45901639344262296

# %%
model["classifier"].estimators_[0].tree_.max_depth
# Out:
# 34

# %%
model_dt["classifier"].tree_.max_depth
# Out:
# 32

# %%
# prompt: build model using xgboost

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
import xgboost as xgb

# Load the dataset
df = pd.read_csv("bank-full.csv", delimiter=";")

# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(
    df.drop("y", axis=1), df["y"], test_size=0.3, random_state=26)

# Define numerical and categorical features
numeric_features = ["age", "balance", "day", "duration",
                    "campaign", "pdays", "previous"]
categorical_features = ["job", "marital", "education",
                        "default", "housing", "loan", "contact",
                        "month", "poutcome"]

# Create transformers for numerical and categorical features
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# Combine transformers using ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features)
])

# Additional evaluation (if needed)
y_test_ = y_test.apply(lambda x: 1 if x=="yes" else 0)
y_pred_num = [1 if x=="yes" else 0 for x in y_pred] #convert string to numeric
print(f1_score(y_test_, y_pred_num))
# Out:
# 0.0

# %%
# build model using xgboost


import xgboost as xgb
# Create and train the XGBoost model
model_xgb = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", xgb.XGBClassifier()) # Use XGBClassifier
])
y_train_ = y_train.apply(lambda x: 1 if x=="yes" else 0)
y_test_ = y_test.apply(lambda x: 1 if x=="yes" else 0)
model_xgb.fit(x_train, y_train_)
# Make predictions and evaluate the model
y_pred = model_xgb.predict(x_test)
print(classification_report(y_test_, y_pred))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-ce3faf884faa> in <cell line: 0>()
#      12 model_xgb.fit(x_train, y_train_)
#      13 # Make predictions and evaluate the model
# ---> 14 y_pred = model_xgb.predict(x_test)
#      15 print(classification_report(y_test_, y_pred))
#      16
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in predict(self, X, **params)
#     780         """
#     781         # TODO(1.8): Remove the context manager and use check_is_fitted(self)
# --> 782         with _raise_or_warn_if_not_fitted(self):
#     783             Xt = X
#     784
#
# /usr/lib/python3.11/contextlib.py in __exit__(self, typ, value, traceback)
#     142         if typ is None:
#     143             try:
# --> 144                 next(self.gen)
#     145             except StopIteration:
#     146                 return False
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in _raise_or_warn_if_not_fitted(estimator)
#      58     # we only get here if the above didn't raise
#      59     try:
# ---> 60         check_is_fitted(estimator)
#      61     except NotFittedError:
#      62         warnings.warn(
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1754         return
#    1755
# -> 1756     if not _is_fitted(estimator, attributes, all_or_any):
#    1757         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1758
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _is_fitted(estimator, attributes, all_or_any)
#    1663
#    1664     if hasattr(estimator, "__sklearn_is_fitted__"):
# -> 1665         return estimator.__sklearn_is_fitted__()
#    1666
#    1667     fitted_attrs = [
#
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py in __sklearn_is_fitted__(self)
#    1319             # means the previous steps should also be fit. This is faster than
#    1320             # checking if every step of the pipeline is fit.
# -> 1321             check_is_fitted(last_step)
#    1322             return True
#    1323         except NotFittedError:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1749         raise TypeError("%s is not an estimator instance." % (estimator))
#    1750
# -> 1751     tags = get_tags(estimator)
#    1752
#    1753     if not tags.requires_fit and attributes is None:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_tags.py in get_tags(estimator)
#     428         for klass in reversed(type(estimator).mro()):
#     429             if "__sklearn_tags__" in vars(klass):
# --> 430                 sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431                 class_order.append(klass)
#     432             elif "_more_tags" in vars(klass):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in __sklearn_tags__(self)
#     538
#     539     def __sklearn_tags__(self):
# --> 540         tags = super().__sklearn_tags__()
#     541         tags.estimator_type = "classifier"
#     542         tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'

# %%
# prompt: stacking model

from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# Define the base estimators
estimators = [
    ('rf', model),  # RandomForestClassifier model
    ('dt', model_dt), # DecisionTreeClassifier model
    ('ada', model_ada) # AdaBoostClassifier model
]

# Define the stacking classifier
stacking_model = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression() # XGBoost as the final estimator
)

# %%
stacking_model
# Out:
# StackingClassifier(estimators=[('rf',
#                                 Pipeline(steps=[('preprocessor',
#                                                  ColumnTransformer(transformers=[('num',
#                                                                                   Pipeline(steps=[('imputer',
#                                                                                                    SimpleImputer(strategy='median')),
#                                                                                                   ('scaler',
#                                                                                                    StandardScaler())]),
#                                                                                   ['age',
#                                                                                    'balance',
#                                                                                    'day',
#                                                                                    'duration',
#                                                                                    'campaign',
#                                                                                    'pdays',
#                                                                                    'previous']),
#                                                                                  ('cat',
#                                                                                   Pipeline(steps=[('imputer',
#                                                                                                    SimpleImputer(fill_value='missing',
#                                                                                                                  strategy='consta...
#                                                                                    'duration',
#                                                                                    'campaign',
#                                                                                    'pdays',
#                                                                                    'previous']),
#                                                                                  ('cat',
#                                                                                   Pipeline(steps=[('imputer',
#                                                                                                    SimpleImputer(fill_value='missing',
#                                                                                                                  strategy='constant')),
#                                                                                                   ('onehot',
#                                                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                                                   ['job',
#                                                                                    'marital',
#                                                                                    'education',
#                                                                                    'default',
#                                                                                    'housing',
#                                                                                    'loan',
#                                                                                    'contact',
#                                                                                    'month',
#                                                                                    'poutcome'])])),
#                                                 ('classifier',
#                                                  AdaBoostClassifier())]))],
#                    final_estimator=LogisticRegression())

# %%
# Train the stacking model
stacking_model.fit(x_train, y_train_)

# Make predictions
y_pred = stacking_model.predict(x_test)

# Evaluate the stacking model
print(classification_report(y_test_, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     11955
#            1       0.64      0.47      0.54      1609
#
#     accuracy                           0.91     13564
#    macro avg       0.79      0.72      0.74     13564
# weighted avg       0.90      0.91      0.90     13564
